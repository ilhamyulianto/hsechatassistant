# %%
import os
import chromadb
from chromadb.config import Settings
from sentence_transformers import SentenceTransformer
from transformers import pipeline

# %% [markdown]
# ## config

# %%
PERSIST_DIR = r"D:\mldlai\hsechatbots\chroma_db"
MODEL_NAME = "intfloat/multilingual-e5-base"  # same as used for embeddings

# Load embedding model for semantic search
embed_model = SentenceTransformer(MODEL_NAME)

# Load persistent Chroma DB
client = chromadb.Client(Settings(persist_directory=PERSIST_DIR))
collection = client.get_collection(name="hse_manual")

print(f"Loaded collection: {collection.name}")
print("Metadata:", collection.metadata)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[3], line 9
#       7 # Load persistent Chroma DB
#       8 client = chromadb.Client(Settings(persist_directory=PERSIST_DIR))
# ----> 9 collection = client.get_collection(name="hse_manual")
#      11 print(f"Loaded collection: {collection.name}")
#      12 print("Metadata:", collection.metadata)
#
# File c:\Users\ilham\miniconda3\envs\llmversion\lib\site-packages\chromadb\api\client.py:208, in Client.get_collection(self, name, embedding_function, data_loader)
#     199 @override
#     200 def get_collection(
#     201     self,
#    (...)
#     206     data_loader: Optional[DataLoader[Loadable]] = None,
#     207 ) -> Collection:
# --> 208     model = self._server.get_collection(
#     209         name=name,
#     210         tenant=self.tenant,
#     211         database=self.database,
#     212     )
# ...
